# %% [markdown]
# # ${\color{Blue}{(Project \ Topic):  }}$  จำนวนผู้เสียชีวิตจากอุบัติเหตุทางถนนของประเทศไทย ระหว่างปี 2560-2564

# %% [markdown]
# ### สมาชิก (Members) :
#
#
# 1.   นายรัตนพงษ์ ภูลับดวง
# 2.   นางสาวอารีรักษ์ กลางอินทร์เดช

# %% [markdown]
# ## ${\color{blue}{ แรงบรรดาลใจในการเลือกหัวข้อนี้ \ (Motivation): }}$

# %% [markdown]
# ในปัจจุบันเกิดอุบัติเหตุขึ้นบ่อยครั้ง ซึ่งทำให้เกิดการเสียชีวิตผู้จัดทำจึงมีความสนใจที่จะนำความรู้ในการเขียนโปรแกรมมาใช้ในการศึกษา สำรวจข้อมูลจำนวนผู้เสียชีวิตจากอุบัติเหตุทางถนนของประเทศไทย ระหว่างปี 2560-2564 เพื่อให้สรุปข้อมูลให้เข้าใจได้ง่ายมากขึ้น

# %% [markdown]
# #${\color{purple}{คำถามที่น่าสนใจเกี่ยวกับปัญหา \ (Interested \ Questions) :}}$

# %% [markdown]
# ลิตส์ของคำถามที่นักศึกษาร่วมกันอภิปรายแล้วให้ความสนใจ และต้องการหาคำตอบโดยอาศัยกระบวนการ Data Engineering and Data Science
#
# ---
#
# 1. จำนวนผู้เสียชีวิตจากบัติเหตุทางถนนของประเทศไทย ระหว่างปี 2560-2564 ในแต่ละปี
# 2. พาหนะใดบ้างที่เกิดอุบัติเหตุบนทางถนนของประเทศไทย ระหว่างปี 2560-2564
# 3. เพศใดบ้างที่เสียชีวิตจากการเกิดอุบัติเหตุทางถนนของประเทศไทย ระหว่างปี 2560-2564
# 4. อายุใดบ้างเสียชีวิตจากการเกิดอุบัติเหตุทางถนนของประเทศไทย ระหว่างปี 2560-2564
#
# ---

# %% [markdown]
# # ${\color{purple}{ข้อมูลที่เกี่ยวข้องในการใช้ตอบคำถามที่สนใจ}}$ ${\color{purple}{\ What \ are \ the \ Data \ related \ to \ answer \ the  \ questions? :}}$

# %% [markdown]
# # ${\color{pink}{ข้อมูลที่จะนำมาวิเคราะห์ \ (Dataset): }}$

# %% [markdown]
# *   1.	ปีที่เสียชีวิต(พศ.) (DEAD_YEAR(Budha))
#     2.	อายุผู้เสียชีวิต (Age)
#     3.	เพศผู้เสียชีวิต (Sex)
#     4.	พาหนะที่ประสบเหตุตามรหัส ICD-10 (Vehicle)

# %% [markdown]
# ## ${\color{pink}{แหล่งที่มาของข้อมูล:}}$

# %% [markdown]
# Dataset ที่ใช้นำมาจากไฟล์ .xlsx จาก https://data.go.th/en/dataset/rtddi?fbclid=IwAR0k_u_U9OHAbp8wyylAoZqRUIMalACW-M0Xqo60LEL69L9ys2F8sk5abBM

# %% [markdown]
# # ${\color{darkGrey}{Exploratory \ Data \  Analysis :}}$

# %% [markdown]
# ## ${\color{Grey}{ Data \ acquisition \ process :}}$
#
# *   แทนข้อความนี้ด้วยไอเดีย หรือกระบวนการในการได้มาซึ่งข้อมูล

# %%
# Scrap/ Load and Preparing Data Set into Pandas DataFrame

# %%
# นำเข้าไลบรารีต่าง ๆ
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
# !pip install -U --pre matplotlib  
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
# ทำการโหลดไฟล์ จาก  Google drive ลงมาที่ current directory
# !gdown --id 17vzuFnYPOWACtc0NgVbuAWv279sCFrdi
#https://docs.google.com/spreadsheets/d/17vzuFnYPOWACtc0NgVbuAWv279sCFrdi/edit?usp=sharing&ouid=109327518805005503397&rtpof=true&sd=true
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=17vzuFnYPOWACtc0NgVbuAWv279sCFrdi
# To: /content/tbl_rtddi .xlsx
# 100% 18.1M/18.1M [00:01<00:00, 11.8MB/s]

# %%
# ทำการอ่านไฟล์สกุล xlsx 
data = pd.read_excel("/content/tbl_rtddi .xlsx")
data
# Out:
#               id  DEAD_YEAR(Budha)  DEAD_YEAR   Age  Sex NationalityId  \
# 0        8596637              2554       2011  16.0  1.0            99
# 1        8596636              2554       2011  14.0  1.0            99
# 2        8609447              2554       2011   NaN  1.0           NaN
# 3        8603763              2554       2011   NaN  1.0           NaN
# 4        8596708              2554       2011  38.0  1.0            99
# ...          ...               ...        ...   ...  ...           ...
# 232164  11417633              2565       2022  16.0  1.0           NaN
# 232165  11417640              2565       2022  62.0  1.0          Thai
# 232166  11417635              2565       2022  29.0  1.0           NaN
# 232167  11422569              2565       2022  23.0  1.0          Thai
# 232168  11417626              2565       2022  16.0  1.0          Thai
#
#              Tumbol     District     Province  RiskHelmet  ...    DeadDate  \
# 0          คลองขนาน    เหนือคลอง           กบ         NaN  ...  2011-01-05
# 1       เกาะศรีบอยา    เหนือคลอง           กบ         NaN  ...  2011-01-05
# 2               NaN          NaN          NaN         NaN  ...  2011-01-14
# 3         ปลายพระยา    ปลายพระยา           กบ         NaN  ...  2011-01-14
# 4            เขาทอง  เมืองกระบี่           กบ         NaN  ...  2011-01-16
# ...             ...          ...          ...         ...  ...         ...
# 232164          NaN          NaN          NaN         NaN  ...  2022-06-19
# 232165          NaN        สำโรง  อุบลราชธานี         NaN  ...  2022-06-20
# 232166          NaN          NaN          NaN         NaN  ...  2022-06-20
# 232167          NaN          NaN          NaN         NaN  ...  2022-06-25
# 232168          NaN     เขื่องใน  อุบลราชธานี         NaN  ...  2022-06-27
#
#            DateRec   Time Rec AccSubDist      AccDist      AccProv     AccLat  \
# 0       2011-01-05   08:00:00   คลองขนาน    เหนือคลอง       กระบี่   8.013613
# 1       2011-01-05   08:00:00   คลองขนาน    เหนือคลอง       กระบี่   8.013613
# 2              NaN        NaN        NaN          NaN       กระบี่        NaN
# 3       2011-01-14   07:20:00  ปลายพระยา    ปลายพระยา       กระบี่   8.532753
# 4       2011-01-16   20:30:00    ทับปริก  เมืองกระบี่       กระบี่   8.142938
# ...            ...        ...        ...          ...          ...        ...
# 232164         NaN        NaN        NaN          NaN  อุบลราชธานี  15.235362
# 232165         NaN        NaN      สำโรง        สำโรง  อุบลราชธานี        NaN
# 232166         NaN        NaN        NaN          NaN  อุบลราชธานี  14.980800
# 232167         NaN        NaN   กลางใหญ่     เขื่องใน  อุบลราชธานี  15.507605
# 232168         NaN        NaN   เขื่องใน     เขื่องใน  อุบลราชธานี        NaN
#
#            AccLong  ICD-10        Vehicle
# 0        99.002554    V299  รถจักรยานยนต์
# 1        99.002554    V299  รถจักรยานยนต์
# 2              NaN     NaN   ไม่ระบุพาหนะ
# 3        98.862684     NaN   ไม่ระบุพาหนะ
# 4        98.891667    V899   ไม่ระบุพาหนะ
# ...            ...     ...            ...
# 232164  105.226675    V892   ไม่ระบุพาหนะ
# 232165         NaN    V892  รถจักรยานยนต์
# 232166  105.173074    V892  รถจักรยานยนต์
# 232167  104.420276     NaN  รถจักรยานยนต์
# 232168         NaN    Y349   ไม่ระบุพาหนะ
#
# [232169 rows x 21 columns]

# %%
# เเสดงจำนวน Row และ Columns ของตาราง
data.shape
# Out:
# (232169, 21)

# %% [markdown]
# ## ${\color{Grey}{ Data \ cleaning \ process :}}$

# %%
# Checking and Cleaning your data

# %%
#เช็คข้อมูลหาความผิดปกติใน DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232169 entries, 0 to 232168
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                232169 non-null  int64
#  1   DEAD_YEAR(Budha)  232169 non-null  int64
#  2   DEAD_YEAR         232169 non-null  int64
#  3   Age               202403 non-null  float64
#  4   Sex               226695 non-null  float64
#  5   NationalityId     130740 non-null  object
#  6   Tumbol            34258 non-null   object
#  7   District          82865 non-null   object
#  8   Province          83021 non-null   object
#  9   RiskHelmet        4390 non-null    float64
#  10  RiskSafetyBelt    2066 non-null    float64
#  11  DeadDate          232169 non-null  object
#  12  DateRec           106950 non-null  object
#  13  Time Rec          106950 non-null  object
#  14  AccSubDist        109454 non-null  object
#  15  AccDist           109919 non-null  object
#  16  AccProv           232169 non-null  object
#  17  AccLat            107713 non-null  float64
#  18  AccLong           107711 non-null  float64
#  19  ICD-10            178781 non-null  object
#  20  Vehicle           232169 non-null  object
# dtypes: float64(6), int64(3), object(12)
# memory usage: 37.2+ MB

# %%
#ลบคอลัมน์ที่ไม่ต้องการออก
data.drop(['id', 'DEAD_YEAR',"Time Rec", 'NationalityId',
       'Tumbol', 'District', 'Province', 'RiskHelmet', 'RiskSafetyBelt',
       'DeadDate', 'AccSubDist', 'AccDist','AccLat',"AccProv", 'AccLong', 'ICD-10', 'DateRec'], axis=1, inplace=True)

# %%
#เปลี่ยนชื่อ columns DEAD_YEAR(Budha)
data.rename(columns={'DEAD_YEAR(Budha)':'DeadYear'},inplace=True)

# %%
#เปลี่ยน type DeadYear และ Sex เป็น string
data['DeadYear'] = data['DeadYear'].astype('string')
data['Sex'] = data['Sex'].astype('string')
data['Vehicle'] = data['Vehicle'].astype('string')

# %%
#ข้อมูลใหม่ที่ต้องการ
data
# Out:
#        DeadYear   Age  Sex        Vehicle
# 0          2554  16.0  1.0  รถจักรยานยนต์
# 1          2554  14.0  1.0  รถจักรยานยนต์
# 2          2554   NaN  1.0   ไม่ระบุพาหนะ
# 3          2554   NaN  1.0   ไม่ระบุพาหนะ
# 4          2554  38.0  1.0   ไม่ระบุพาหนะ
# ...         ...   ...  ...            ...
# 232164     2565  16.0  1.0   ไม่ระบุพาหนะ
# 232165     2565  62.0  1.0  รถจักรยานยนต์
# 232166     2565  29.0  1.0  รถจักรยานยนต์
# 232167     2565  23.0  1.0  รถจักรยานยนต์
# 232168     2565  16.0  1.0   ไม่ระบุพาหนะ
#
# [232169 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232169 entries, 0 to 232168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DeadYear  232169 non-null  string
#  1   Age       202403 non-null  float64
#  2   Sex       226695 non-null  string
#  3   Vehicle   232169 non-null  string
# dtypes: float64(1), string(3)
# memory usage: 7.1 MB

# %%
#เลือกข้อมูล 2560-2564
data = data[(data.DeadYear >= '2560') & (data.DeadYear <= '2564' ) ]
data
# Out:
#        DeadYear   Age   Sex        Vehicle
# 1096       2560  12.0   2.0  รถจักรยานยนต์
# 1097       2560  13.0   2.0  รถจักรยานยนต์
# 1098       2560  35.0   1.0         รถยนต์
# 1099       2560  16.0   1.0  รถจักรยานยนต์
# 1100       2560  36.0   1.0  รถจักรยานยนต์
# ...         ...   ...   ...            ...
# 231917     2564   NaN   1.0   ไม่ระบุพาหนะ
# 231918     2564  67.0  <NA>  รถจักรยานยนต์
# 231919     2564  24.0  <NA>  รถจักรยานยนต์
# 231920     2564  66.0  <NA>  รถจักรยานยนต์
# 231921     2564  29.0  <NA>  รถจักรยานยนต์
#
# [96230 rows x 4 columns]

# %%
#ตรวจสอบค่าที่หายไป
print(data.isnull().sum())
# Out:
# DeadYear       0
# Age         4282
# Sex         5051
# Vehicle        0
# dtype: int64

# %%
#หาค่า mode median ที่จะแทนค่าลงไปแทนค่า Age , Sex ที่ NaN
df = data.copy()
val1 = df["Age"].median()
val2 = df["Sex"].mode().max()
val1, val2
# Out:
# (39.0, '1.0')

# %%
#แทนค่า Age ที่ว่างด้วยค่า  median และ Sex ที่ว่าง ด้วยค่า mode
df["Age"].fillna(val1, inplace = True)
df["Sex"].fillna(val2, inplace = True)
df
# Out:
#        DeadYear   Age  Sex        Vehicle
# 1096       2560  12.0  2.0  รถจักรยานยนต์
# 1097       2560  13.0  2.0  รถจักรยานยนต์
# 1098       2560  35.0  1.0         รถยนต์
# 1099       2560  16.0  1.0  รถจักรยานยนต์
# 1100       2560  36.0  1.0  รถจักรยานยนต์
# ...         ...   ...  ...            ...
# 231917     2564  39.0  1.0   ไม่ระบุพาหนะ
# 231918     2564  67.0  1.0  รถจักรยานยนต์
# 231919     2564  24.0  1.0  รถจักรยานยนต์
# 231920     2564  66.0  1.0  รถจักรยานยนต์
# 231921     2564  29.0  1.0  รถจักรยานยนต์
#
# [96230 rows x 4 columns]

# %%
#เช็คว่า Age มีค่ามากว่า 100 ไหม
df[df.Age > 100]
# Out:
#        DeadYear    Age  Sex                 Vehicle
# 13492      2560  149.0  1.0           รถจักรยานยนต์
# 14232      2562  149.0  1.0           รถจักรยานยนต์
# 14680      2564  149.0  1.0  รถบรรทุกขนาดเล็ก/รถตู้
# 59942      2562  119.0  1.0           รถจักรยานยนต์
# 160926     2562  149.0  1.0           รถจักรยานยนต์
# 190508     2560  149.0  1.0           รถจักรยานยนต์
# 211521     2561  110.0  2.0            ไม่ระบุพาหนะ
# 225136     2563  149.0  1.0           รถจักรยานยนต์

# %%
np.sum(df.Age > 100)
# Out:
# 8

# %%
np.sum(df.Age < 0)
# Out:
# 0

# %%
#ดูว่ามีค่านอกเกณฑ์ไหม
sns.boxplot(df.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#จัดการกับค่าผิดปกติของ Age ด้วยสมการของ boxplots
#หาค่า Q1, Q3
q3 = df['Age'].quantile(.75)
q1 = df['Age'].quantile(.25)

#คำนวณหาช่วงข้อมูล Age
iqr = q3 - q1
upper = q3 + (1.5 * iqr)
lower = q1 - (1.5 * iqr)
print(f'q3 : {q3}\nq1 : {q1}\niqr : {iqr}')
print(f'upper : {upper}\nlower : {lower}')
# Out:
# q3 : 55.0
# q1 : 24.0
# iqr : 31.0
# upper : 101.5
# lower : -22.5

# %%
#แสดงข้อมูล 2 รายการที่มีค่า Age > upper
outlier = df['Age'] > upper
df[outlier]
# Out:
#        DeadYear    Age  Sex                 Vehicle
# 13492      2560  149.0  1.0           รถจักรยานยนต์
# 14232      2562  149.0  1.0           รถจักรยานยนต์
# 14680      2564  149.0  1.0  รถบรรทุกขนาดเล็ก/รถตู้
# 59942      2562  119.0  1.0           รถจักรยานยนต์
# 160926     2562  149.0  1.0           รถจักรยานยนต์
# 190508     2560  149.0  1.0           รถจักรยานยนต์
# 211521     2561  110.0  2.0            ไม่ระบุพาหนะ
# 225136     2563  149.0  1.0           รถจักรยานยนต์

# %%
#ลบข้อมูล 2 รายการที่เป็นค่าผิดปกติของขอบบน
df.drop(df[outlier].index, inplace = True)
df
# Out:
#        DeadYear   Age  Sex        Vehicle
# 1096       2560  12.0  2.0  รถจักรยานยนต์
# 1097       2560  13.0  2.0  รถจักรยานยนต์
# 1098       2560  35.0  1.0         รถยนต์
# 1099       2560  16.0  1.0  รถจักรยานยนต์
# 1100       2560  36.0  1.0  รถจักรยานยนต์
# ...         ...   ...  ...            ...
# 231917     2564  39.0  1.0   ไม่ระบุพาหนะ
# 231918     2564  67.0  1.0  รถจักรยานยนต์
# 231919     2564  24.0  1.0  รถจักรยานยนต์
# 231920     2564  66.0  1.0  รถจักรยานยนต์
# 231921     2564  29.0  1.0  รถจักรยานยนต์
#
# [96222 rows x 4 columns]

# %%
#แสดงข้อมูล 2 รายการที่มีค่า Age < lower
outlier = df['Age'] < lower
df[outlier]

#ลบข้อมูล 2 รายการที่เป็นค่าผิดปกติของขอบล่าง
df.drop(df[outlier].index, inplace = True )

#reset_index ให้เรียงลำดับ 0,1,2
df.reset_index(drop=True, inplace = True)
print(df)
# Out:
#       DeadYear   Age  Sex        Vehicle
# 0         2560  12.0  2.0  รถจักรยานยนต์
# 1         2560  13.0  2.0  รถจักรยานยนต์
# 2         2560  35.0  1.0         รถยนต์
# 3         2560  16.0  1.0  รถจักรยานยนต์
# 4         2560  36.0  1.0  รถจักรยานยนต์
# ...        ...   ...  ...            ...
# 96217     2564  39.0  1.0   ไม่ระบุพาหนะ
# 96218     2564  67.0  1.0  รถจักรยานยนต์
# 96219     2564  24.0  1.0  รถจักรยานยนต์
# 96220     2564  66.0  1.0  รถจักรยานยนต์
# 96221     2564  29.0  1.0  รถจักรยานยนต์
#
# [96222 rows x 4 columns]

# %%
sns.boxplot(df.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#หาจำนวนข้อมูลแถวซ้ำกัน
np.sum(df.duplicated())
# Out:
# 91485

# %%
#ลบข้อมูลแถวซ้ำกัน
df.drop_duplicates(inplace = True)
df
# Out:
#       DeadYear   Age  Sex                 Vehicle
# 0         2560  12.0  2.0           รถจักรยานยนต์
# 1         2560  13.0  2.0           รถจักรยานยนต์
# 2         2560  35.0  1.0                  รถยนต์
# 3         2560  16.0  1.0           รถจักรยานยนต์
# 4         2560  36.0  1.0           รถจักรยานยนต์
# ...        ...   ...  ...                     ...
# 95750     2564  52.0  2.0            รถบรรทุกหนัก
# 95854     2564   9.0  2.0  รถบรรทุกขนาดเล็ก/รถตู้
# 95878     2564  87.0  2.0           รถจักรยานยนต์
# 95968     2564  43.0  1.0               รถจักรยาน
# 96108     2564   4.0  2.0              คนเดินเท้า
#
# [4737 rows x 4 columns]

# %%
#reset index ใหม่
df.reset_index(drop=True, inplace = True)
df
# Out:
#      DeadYear   Age  Sex                 Vehicle
# 0        2560  12.0  2.0           รถจักรยานยนต์
# 1        2560  13.0  2.0           รถจักรยานยนต์
# 2        2560  35.0  1.0                  รถยนต์
# 3        2560  16.0  1.0           รถจักรยานยนต์
# 4        2560  36.0  1.0           รถจักรยานยนต์
# ...       ...   ...  ...                     ...
# 4732     2564  52.0  2.0            รถบรรทุกหนัก
# 4733     2564   9.0  2.0  รถบรรทุกขนาดเล็ก/รถตู้
# 4734     2564  87.0  2.0           รถจักรยานยนต์
# 4735     2564  43.0  1.0               รถจักรยาน
# 4736     2564   4.0  2.0              คนเดินเท้า
#
# [4737 rows x 4 columns]

# %%
#แสดงข้อมูลสรุปทางสถิติของคอลัมน์
df.describe(include='all')
# Out:
#        DeadYear          Age   Sex       Vehicle
# count      4737  4737.000000  4737          4737
# unique        5          NaN     3            10
# top        2560          NaN   1.0  ไม่ระบุพาหนะ
# freq       1041          NaN  2683           933
# mean        NaN    45.678277   NaN           NaN
# std         NaN    24.863758   NaN           NaN
# min         NaN     0.000000   NaN           NaN
# 25%         NaN    25.000000   NaN           NaN
# 50%         NaN    47.000000   NaN           NaN
# 75%         NaN    66.000000   NaN           NaN
# max         NaN   100.000000   NaN           NaN

# %%
df['Age'].hist(bins = 10)
plt.title('Age')
plt.show()

# %%
#แสดงการแจกแจงของข้อมูล Age
sns.distplot(df['Age'], bins = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#ในแต่ละปีนี้มีผู้เสียชีวิตจากอุบัติเหตุจำนวนเท่าใด
df.groupby('DeadYear').size()
# Out:
# DeadYear
# 2560    1041
# 2561     977
# 2562     915
# 2563     922
# 2564     882
# dtype: int64

# %%
#ดูว่าแต่ละอายุมีผู้เสียชีวิตจากอุบัติเหตุไปเท่าใด
df.groupby('Age').size()
# Out:
# Age
# 0.0      43
# 1.0      47
# 2.0      42
# 3.0      41
# 4.0      44
#          ..
# 96.0      4
# 97.0      2
# 98.0      2
# 99.0      1
# 100.0     1
# Length: 101, dtype: int64

# %%
#ดูว่าแต่ละเพศมีผู้เสียชีวิตจากอุบัติเหตุไปเท่าใด
df.groupby('Sex').size()
# Out:
# Sex
# 0.0       4
# 1.0    2683
# 2.0    2050
# dtype: int64

# %%
#ดูว่าพาหนะแต่ละชนิดเกิดอุบัติเหตุไปเท่าใด 
df.groupby('Vehicle').size()
# Out:
# Vehicle
# คนเดินเท้า                740
# รถจักรยาน                 217
# รถจักรยานยนต์             916
# รถบรรทุกขนาดเล็ก/รถตู้    609
# รถบรรทุกหนัก              231
# รถยนต์                    838
# รถเพื่อการเกษตร            64
# รถโดยสาร                   73
# สามล้อ                    116
# ไม่ระบุพาหนะ              933
# dtype: int64

# %% [markdown]
# #Model

# %% [markdown]
# ปีพ.ศ.2560-2564

# %%
df.DeadYear.value_counts().plot(kind="bar",figsize=(8, 8),fontsize = 12)
plt.title("Value counts of the DeadYear variable",fontsize=17)
plt.xlabel("Year",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
df.Vehicle.value_counts().plot(kind="barh",figsize=(10, 10),fontsize = 12)
plt.title("Value counts of the Vehicle variable",fontsize=17)
plt.xlabel("Count",fontsize=17)
plt.xticks(rotation=1)
plt.ylabel("Vehicle",fontsize=17)
plt.show()

# %%
df.Sex.value_counts().plot(kind="bar",figsize=(8, 8),fontsize = 12)
plt.title("Value counts of the Sex variable",fontsize=17)
plt.xlabel("Sex",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
df['Age'].hist(bins=[0,20,40,60,80,100])
plt.title("Value counts of the Age variable",fontsize=17)
plt.xlabel("Age",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %% [markdown]
# #ข้อมูลในแต่ละปี

# %% [markdown]
# ปี พ.ศ. 2560

# %%
df60 = df[(df.DeadYear == '2560') ]

# %%
df60.Vehicle.value_counts()
# Out:
# รถจักรยานยนต์             188
# ไม่ระบุพาหนะ              185
# รถยนต์                    171
# คนเดินเท้า                168
# รถบรรทุกขนาดเล็ก/รถตู้    134
# รถจักรยาน                  72
# รถบรรทุกหนัก               59
# สามล้อ                     36
# รถโดยสาร                   18
# รถเพื่อการเกษตร            10
# Name: Vehicle, dtype: Int64

# %%
df60.Sex.value_counts()
# Out:
# 1.0    578
# 2.0    461
# 0.0      2
# Name: Sex, dtype: Int64

# %%
df60.Age.value_counts()
# Out:
# 43.0    16
# 47.0    15
# 68.0    15
# 59.0    15
# 56.0    15
#         ..
# 94.0     2
# 91.0     2
# 93.0     2
# 96.0     1
# 98.0     1
# Name: Age, Length: 98, dtype: int64

# %%
df60.Vehicle.value_counts().plot(kind="barh",figsize=(10, 10),fontsize = 12)
plt.title("Value counts of the Vehicle variable in 2560",fontsize=17)
plt.xlabel("Count",fontsize=17)
plt.xticks(rotation=1)
plt.ylabel("Vehicle",fontsize=17)
plt.show()

# %%
df60.Sex.value_counts().plot(kind="bar",figsize=(6, 6),fontsize = 12)
plt.title("Value counts of the Sex variable in 2560 ",fontsize=17)
plt.xlabel("Sex",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
df60['Age'].hist(bins=[0,20,40,60,80,100])
plt.title("Value counts of the Age variable in 2560",fontsize=17)
plt.xlabel("Age",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %% [markdown]
# ปี พ.ศ.2561

# %%
df61 = df[(df.DeadYear == '2561') ]

# %%
df61.Vehicle.value_counts()
# Out:
# ไม่ระบุพาหนะ              185
# รถจักรยานยนต์             180
# รถยนต์                    175
# คนเดินเท้า                151
# รถบรรทุกขนาดเล็ก/รถตู้    116
# รถจักรยาน                  57
# รถบรรทุกหนัก               45
# รถโดยสาร                   32
# สามล้อ                     22
# รถเพื่อการเกษตร            14
# Name: Vehicle, dtype: Int64

# %%
df61.Sex.value_counts()
# Out:
# 1.0    559
# 2.0    417
# 0.0      1
# Name: Sex, dtype: Int64

# %%
df61.Age.value_counts()
# Out:
# 58.0    15
# 56.0    15
# 63.0    15
# 51.0    14
# 49.0    14
#         ..
# 91.0     2
# 92.0     1
# 94.0     1
# 97.0     1
# 98.0     1
# Name: Age, Length: 97, dtype: int64

# %%
df61.Vehicle.value_counts().plot(kind="barh",figsize=(10, 10),fontsize = 12)
plt.title("Value counts of the Vehicle variable in 2561",fontsize=17)
plt.xlabel("Count",fontsize=17)
plt.xticks(rotation=1)
plt.ylabel("Vehicle",fontsize=17)
plt.show()


df61.Sex.value_counts().plot(kind="bar",figsize=(6, 6),fontsize = 12)
plt.title("Value counts of the Sex variable in 2561 ",fontsize=17)
plt.xlabel("Sex",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()


df61['Age'].hist(bins=[0,20,40,60,80,100])
plt.title("Value counts of the Age variable in 2561",fontsize=17)
plt.xlabel("Age",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %% [markdown]
# ปี พ.ศ.2562

# %%
df62 = df[(df.DeadYear == '2562') ]

# %%
df62.Vehicle.value_counts()
# Out:
# ไม่ระบุพาหนะ              189
# รถจักรยานยนต์             184
# รถยนต์                    167
# คนเดินเท้า                145
# รถบรรทุกขนาดเล็ก/รถตู้    119
# รถบรรทุกหนัก               49
# รถจักรยาน                  27
# สามล้อ                     14
# รถเพื่อการเกษตร            14
# รถโดยสาร                    7
# Name: Vehicle, dtype: Int64

# %%
df62.Sex.value_counts()
# Out:
# 1.0    520
# 2.0    394
# 0.0      1
# Name: Sex, dtype: Int64

# %%
df62.Age.value_counts()
# Out:
# 61.0    15
# 48.0    14
# 62.0    14
# 60.0    13
# 39.0    13
#         ..
# 91.0     3
# 96.0     2
# 94.0     1
# 95.0     1
# 93.0     1
# Name: Age, Length: 97, dtype: int64

# %%
df62.Vehicle.value_counts().plot(kind="barh",figsize=(10, 10),fontsize = 12)
plt.title("Value counts of the Vehicle variable in 2562",fontsize=17)
plt.xlabel("Count",fontsize=17)
plt.xticks(rotation=1)
plt.ylabel("Vehicle",fontsize=17)
plt.show()


df62.Sex.value_counts().plot(kind="bar",figsize=(6, 6),fontsize = 12)
plt.title("Value counts of the Sex variable in 2562 ",fontsize=17)
plt.xlabel("Sex",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()


df62['Age'].hist(bins=[0,20,40,60,80,100])
plt.title("Value counts of the Age variable in 2562",fontsize=17)
plt.xlabel("Age",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %% [markdown]
# ปี พ.ศ.2563

# %%
df63 = df[(df.DeadYear == '2563') ]

# %%
df63.Vehicle.value_counts()
# Out:
# ไม่ระบุพาหนะ              185
# รถจักรยานยนต์             182
# รถยนต์                    172
# คนเดินเท้า                143
# รถบรรทุกขนาดเล็ก/รถตู้    124
# รถบรรทุกหนัก               31
# รถจักรยาน                  30
# สามล้อ                     26
# รถเพื่อการเกษตร            16
# รถโดยสาร                   13
# Name: Vehicle, dtype: Int64

# %%
df63.Sex.value_counts()
# Out:
# 1.0    515
# 2.0    407
# Name: Sex, dtype: Int64

# %%
df63.Age.value_counts()
# Out:
# 54.0    15
# 57.0    14
# 63.0    13
# 48.0    13
# 67.0    13
#         ..
# 91.0     2
# 94.0     2
# 95.0     1
# 99.0     1
# 93.0     1
# Name: Age, Length: 97, dtype: int64

# %%
df63.Vehicle.value_counts().plot(kind="barh",figsize=(10, 10),fontsize = 12)
plt.title("Value counts of the Vehicle variable in 2563",fontsize=17)
plt.xlabel("Count",fontsize=17)
plt.xticks(rotation=1)
plt.ylabel("Vehicle",fontsize=17)
plt.show()


df63.Sex.value_counts().plot(kind="bar",figsize=(6, 6),fontsize = 12)
plt.title("Value counts of the Sex variable in 2563 ",fontsize=17)
plt.xlabel("Sex",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()


df63['Age'].hist(bins=[0,20,40,60,80,100])
plt.title("Value counts of the Age variable in 2563",fontsize=17)
plt.xlabel("Age",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()

# %% [markdown]
# ปี พ.ศ.2564

# %%
df64 = df[(df.DeadYear == '2564') ]

# %%
df64.Vehicle.value_counts()
# Out:
# ไม่ระบุพาหนะ              189
# รถจักรยานยนต์             182
# รถยนต์                    153
# คนเดินเท้า                133
# รถบรรทุกขนาดเล็ก/รถตู้    116
# รถบรรทุกหนัก               47
# รถจักรยาน                  31
# สามล้อ                     18
# รถเพื่อการเกษตร            10
# รถโดยสาร                    3
# Name: Vehicle, dtype: Int64

# %%
df64.Sex.value_counts()
# Out:
# 1.0    511
# 2.0    371
# Name: Sex, dtype: Int64

# %%
df64.Age.value_counts()
# Out:
# 64.0     15
# 60.0     13
# 67.0     13
# 68.0     13
# 52.0     13
#          ..
# 95.0      2
# 96.0      1
# 93.0      1
# 97.0      1
# 100.0     1
# Name: Age, Length: 99, dtype: int64

# %%
df64.Vehicle.value_counts().plot(kind="barh",figsize=(10, 10),fontsize = 12)
plt.title("Value counts of the Vehicle variable in 2564",fontsize=17)
plt.xlabel("Count",fontsize=17)
plt.xticks(rotation=1)
plt.ylabel("Vehicle",fontsize=17)
plt.show()


df64.Sex.value_counts().plot(kind="bar",figsize=(6, 6),fontsize = 12)
plt.title("Value counts of the Sex variable in 2564 ",fontsize=17)
plt.xlabel("Sex",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()


df64['Age'].hist(bins=[0,20,40,60,80,100])
plt.title("Value counts of the Age variable in 2564",fontsize=17)
plt.xlabel("Age",fontsize=17)
plt.xticks(rotation=0)
plt.ylabel("Count",fontsize=17)
plt.show()
